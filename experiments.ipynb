# %%
# importing libraries
import warnings
warnings.filterwarnings('ignore')
import os
import openai
import langchain
import pinecone
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Pinecone
from langchain.llms import OpenAI

# %%
# importing load_dotenv
from dotenv import load_dotenv
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# #### Step 1:

# %%
# creating a function to read any kind of pdf file
def read_doc(directory):
    file_loader=PyPDFDirectoryLoader(directory)
    documents=file_loader.load()
    return documents

# %%
doc=read_doc('documents/')

# %%
# output
doc
len(doc)
# Out:
# 2

# %% [markdown]
# #### Step 2:
# -- divide the pdf into text_chunks

# %%
# creating a function which divide the docs into chunks
# here we call the RecursiveCharacterTextSplitter() class
# making an object
def chunk_data(docs, chunk_size=800,chunk_overlap=50):
    text_splitter=RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap
    )
    doc=text_splitter.split_documents(docs)
    return doc

# %%
documents=chunk_data(doc)
documents
# Out:
# [Document(page_content='BUDGET AT A GLANCE(Taka in Crore ) 1\nDescription\n2022-23 2021-22 2021-22Revised Budget Budget Actual\n2020-21\nRevenue and Foreign Grants\nRevenues (Statement I)  3,28,665  3,89,000  4,33,000  3,89,000\n     Tax Revenue  2,69,803  3,46,000  3,88,000  3,46,000\n          NBR Tax Revenue  2,63,886  3,30,000  3,70,000  3,30,000\n          Non-NBR Tax Revenue    5,917   16,000   18,000   16,000\n     Non-Tax Revenue   58,862   43,000   45,000   43,000\nForeign Grants/1 (Statement V)    2,348    3,490    3,271    3,192\n 4,36,271  3,92,192  3,92,490 Total :  3,31,013\nExpenditure\nOperating Expenditure  2,85,830  3,61,500  4,11,406  3,66,627\n     Recurrent Expenditure (Statement III)  2,65,893  3,28,840  3,73,242  3,40,572\n                    of which Interest   70,606   68,213   79,530   71,213', metadata={'source': 'documents\\budget.pdf', 'page': 0}),
#  Document(page_content='Domestic Interest   66,319   62,000   73,175   65,000\n                              Foreign Interest    4,287    6,589    7,200    6,244\n      Capital Expenditure/2 (Statement IV)   19,937   32,660   38,164   26,056\nNet Outlay for Food Account Operation/3  (Statement VIII)    4,246     597     540     136\nLoans & Advances (Net)/4 (Statement VIA)     593    4,506    6,501    4,789\nDevelopment Expenditure  1,69,491  2,37,078  2,59,617  2,21,948\n     Scheme/5 (Statement X)    2,721    3,176    3,155    3,040\n     Non-ADP Special Project (Statement VIA)    4,108    5,990    7,721    6,336\n     Annual Development Programme/6 (Statement IX)  1,60,495  2,25,324  2,46,066  2,09,977\n     Non-ADP FFW and Transfer/7 (Statement X)    2,166    2,588    2,675    2,595', metadata={'source': 'documents\\budget.pdf', 'page': 0}),
#  Document(page_content='6,78,064  5,93,500  6,03,681\n- 2,41,793 - 2,01,308 - 2,11,191\n- 2,45,064 - 2,04,500 - 2,14,681- 5.4 - 5.1 - 6.1\n- 6.2 - 5.1 - 5.5Total - Expenditure :\nOverall Deficit (Including Grants) :\n(In percent of GDP) :\n(In percent of GDP) :Overall Deficit (Excluding Grants) : 4,60,160\n- 1,29,147\n- 4.1\n- 1,31,495\n- 4.1\nFinancing\nForeign Borrowing-Net   45,708   97,738   95,458   77,020\n     Foreign Borrowing (Statement V)   57,726  1,12,188  1,12,458   91,812\n     Foreign Debt Repayment (Statement IX) -  12,018 -  14,450 -  17,000 -  14,792\nDomestic Borrowing (Statement VIB)   82,586  1,13,453  1,46,335  1,24,288\n     Borrowing from Banking System (Net)   32,673   76,452  1,06,334   87,287\n             Long-Term Debt (Net)   50,692   51,600   68,192   62,435', metadata={'source': 'documents\\budget.pdf', 'page': 0}),
#  Document(page_content='Short-Term Debt (Net) -  18,019   24,852   38,142   24,852', metadata={'source': 'documents\\budget.pdf', 'page': 0}),
#  Document(page_content='BUDGET AT A GLANCE(Taka in Crore ) 2\nDescription\n2022-23 2021-22 2021-22Revised Budget Budget Actual\n2020-21\n     Non-Bank Borrowing (Net)   49,913   37,001   40,001   37,001\n             National Savings Schemes (Net)   43,040   32,000   35,000   32,000\n             Others (Net)/8 (Statement VII)    6,873    5,001    5,001    5,001\n 2,41,793  2,01,308  2,11,191 Total - Financing :  1,28,294\nGDP 44,49,959 39,76,462 34,56,040Memorandum Item :31,71,800\nEXPLANATORY NOTES :\n1.\n2.\n4.\n5.\n7.Grants have been grouped together with government revenues as they are unrequitted receipts from development partners;\nExpenditure for acquisition of assets, acquisition of land, construction and works, and investment in shares and equities etc. \nhave been included in Operating Capital Expenditure;', metadata={'source': 'documents\\budget.pdf', 'page': 1}),
#  Document(page_content='Loans and Advances to state -owned enterprises/autonomous bodies and government employees minus repayment of loans and \nadvances have been shown as Loans and Advances (Net);\nScheme is one of the three kind of Non- ADP Projects , other two are - Food for Works & Transfers and Non -ADP Special Projects .\nScheme includes some development programmes that are financed from Own Source Revenue but not included in the ADP ;\nTransfer of sale proceeds from food grains received under the agreement with development partners & part of  Food For Works \n(FFW) programme which are not included in the ADP have been shown under this category ;\nNet increase/ decrease in the Public Accounts of the Republic (excluding National Savings Schemes) has been included in this', metadata={'source': 'documents\\budget.pdf', 'page': 1}),
#  Document(page_content='group.6.Including Self Financed Tk . 7,104 crore of the Autonomous Bodies /State Owned Enterprises and Export Credit Agency (E.C.A) \nand bidders financing supported financing Tk . 2,833 crore total size of the Annual Development Program stands at Tk . 2,56,003 \ncrore;3.\n8. As per GDP, 2005-06 has been considered as the base year for the actual account of FY2020-21 and the original budget of \nFY2021-22, while 2015-16 has been considered as the base year for the revised budget of FY2021-22 and the budget of \nFY2022-23.', metadata={'source': 'documents\\budget.pdf', 'page': 1})]

# %%
# Out:
# [Document(page_content='', metadata={'source': 'documents\\living.pdf', 'page': 0}),
#  Document(page_content='', metadata={'source': 'documents\\living.pdf', 'page': 1}),
#  Document(page_content='', metadata={'source': 'documents\\living.pdf', 'page':